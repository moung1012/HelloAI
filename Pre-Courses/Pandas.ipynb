# %% [markdown]
# # Pandas

# %% [markdown]
# ## 자료구조 : Seires와 Dataframe
#
# Pandas에서 제공하는 데이터 자료구조는 Series와 Dataframe 두가지가 존재하는데 Series는 시계열과 유사한 데이터로서 index와 value가 존재하고 Dataframe은 딕셔너리데이터를 매트릭스 형태로 만들어 준 것 같은 frame을 가지고 있다. 이런 데이터 구조를 통해 시계열, 비시계열 데이터를 통합하여 다룰 수 있다.

# %% [markdown]
# ## Series

# %%
#이부분을 진행 할때 pasdas가 없다고 오류가 나면 아래 명령을 실행한다. 

# !pip3 install pandas
# Out:
# ns.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/
#     copying numpy/random/bit_generator.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/
#     copying numpy/random/_bounded_integers.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/
#     copying numpy/random/__init__.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/
#     copying numpy/random/_common.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/
#     copying numpy/random/__init__.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/
#     copying numpy/testing/__init__.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/testing/
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/scalars.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/array_constructors.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/array_like.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/numerictypes.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/warnings_and_errors.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/ufuncs.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/modules.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/flatiter.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/dtype.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/fromnumeric.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/bitwise_ops.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/ndarray_misc.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/constants.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/ndarray.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/ufunc_config.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     copying numpy/typing/tests/data/fail/arithmetic.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/fail
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/dtype.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/arithmetic.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/numeric.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/array_constructors.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/flatiter.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/array_like.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/numerictypes.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/bitwise_ops.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/simple_py3.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/warnings_and_errors.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/ndarray_misc.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/modules.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/fromnumeric.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/mod.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/ndarray_conversion.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/scalars.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/simple.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/literal.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/ufuncs.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/ufunc_config.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     copying numpy/typing/tests/data/pass/ndarray_shape_manipulation.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/pass
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/flatiter.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/scalars.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/nbit_base_example.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/fromnumeric.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/ndarray_shape_manipulation.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/numeric.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/arithmetic.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/modules.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/ndarray_misc.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/ufunc_config.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/warnings_and_errors.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/ndarray_conversion.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/mod.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/dtype.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/bitwise_ops.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/constants.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/numerictypes.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/reveal/array_constructors.py -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/reveal
#     copying numpy/typing/tests/data/mypy.ini -> build/bdist.macosx-10.9-universal2/wheel/numpy/typing/tests/data/
#     copying numpy/__init__.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/
#     copying numpy/py.typed -> build/bdist.macosx-10.9-universal2/wheel/numpy/
#     copying numpy/rec.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/
#     copying numpy/ctypeslib.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/
#     copying numpy/emath.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/
#     copying numpy/char.pyi -> build/bdist.macosx-10.9-universal2/wheel/numpy/
#     copying LICENSE.txt -> build/bdist.macosx-10.9-universal2/wheel/numpy
#     copying numpy/__init__.cython-30.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy
#     copying numpy/__init__.pxd -> build/bdist.macosx-10.9-universal2/wheel/numpy
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/include/numpy/_numpyconfig.h -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/include/numpy
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/include/numpy/__multiarray_api.h -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/include/numpy
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/include/numpy/multiarray_api.txt -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/include/numpy
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/include/numpy/__ufunc_api.h -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/include/numpy
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/include/numpy/ufunc_api.txt -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/include/numpy
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/core/lib
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/core/lib/npy-pkg-config
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/lib/npy-pkg-config/npymath.ini -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/lib/npy-pkg-config
#     copying build/src.macosx-10.9-universal2-3.9/numpy/core/lib/npy-pkg-config/mlib.ini -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/lib/npy-pkg-config
#     running install_clib
#     copying build/temp.macosx-10.9-universal2-3.9/libnpymath.a -> build/bdist.macosx-10.9-universal2/wheel/numpy/core/lib
#     creating build/bdist.macosx-10.9-universal2/wheel/numpy/random/lib
#     copying build/temp.macosx-10.9-universal2-3.9/libnpyrandom.a -> build/bdist.macosx-10.9-universal2/wheel/numpy/random/lib
#     running install_egg_info
#     running egg_info
#     writing numpy.egg-info/PKG-INFO
#     writing dependency_links to numpy.egg-info/dependency_links.txt
#     writing entry points to numpy.egg-info/entry_points.txt
#     writing top-level names to numpy.egg-info/top_level.txt
#     reading manifest file 'numpy.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     no previously-included directories found matching 'doc/build'
#     no previously-included directories found matching 'doc/source/generated'
#     no previously-included directories found matching 'benchmarks/env'
#     no previously-included directories found matching 'benchmarks/results'
#     no previously-included directories found matching 'benchmarks/html'
#     no previously-included directories found matching 'benchmarks/numpy'
#     warning: no previously-included files matching '*.pyo' found anywhere in distribution
#     warning: no previously-included files matching '*.pyd' found anywhere in distribution
#     warning: no previously-included files matching '*.swp' found anywhere in distribution
#     warning: no previously-included files matching '*.bak' found anywhere in distribution
#     warning: no previously-included files matching '*~' found anywhere in distribution
#     warning: no previously-included files found matching 'LICENSES_bundled.txt'
#     writing manifest file 'numpy.egg-info/SOURCES.txt'
#     Copying numpy.egg-info to build/bdist.macosx-10.9-universal2/wheel/numpy-1.20.1-py3.9.egg-info
#     running install_scripts
#     [WARNING] This wheel needs a higher macOS version than the version your Python interpreter is compiled against.  To silence this warning, set MACOSX_DEPLOYMENT_TARGET to at least 11_0 or recreate these files with lower MACOSX_DEPLOYMENT_TARGET:
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_operand_flag_tests.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_multiarray_umath.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_simd.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_rational_tests.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_umath_tests.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_struct_ufunc_tests.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/core/_multiarray_tests.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/linalg/lapack_lite.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/linalg/_umath_linalg.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/fft/_pocketfft_internal.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/bit_generator.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/mtrand.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_generator.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_pcg64.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_sfc64.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_mt19937.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_philox.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_bounded_integers.cpython-39-darwin.so
#     build/bdist.macosx-10.9-universal2/wheel/numpy/random/_common.cpython-39-darwin.soTraceback (most recent call last):
#       File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pip/_vendor/pep517/_in_process.py", line 280, in <module>
#         main()
#       File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pip/_vendor/pep517/_in_process.py", line 263, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pip/_vendor/pep517/_in_process.py", line 204, in build_wheel
#         return _build_backend().build_wheel(wheel_directory, config_settings,
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 211, in build_wheel
#         return self._build_with_temp_dir(['bdist_wheel'], '.whl',
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 197, in _build_with_temp_dir
#         self.run_setup()
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 248, in run_setup
#         super(_BuildMetaLegacyBackend,
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 142, in run_setup
#         exec(compile(code, __file__, 'exec'), locals())
#       File "setup.py", line 513, in <module>
#         setup_package()
#       File "setup.py", line 505, in setup_package
#         setup(**metadata)
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-install-fq5ait8j/numpy/numpy/distutils/core.py", line 169, in setup
#         return old_setup(**new_attr)
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/setuptools/__init__.py", line 165, in setup
#         return distutils.core.setup(**attrs)
#       File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 328, in run
#         impl_tag, abi_tag, plat_tag = self.get_tag()
#       File "/private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-qum05bkx/overlay/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 278, in get_tag
#         assert tag in supported_tags, "would build wheel with unsupported tag {}".format(tag)
#     AssertionError: would build wheel with unsupported tag ('cp39', 'cp39', 'macosx_11_0_universal2')
#
#     ########### EXT COMPILER OPTIMIZATION ###########
#     Platform      :
#       Architecture: unsupported
#       Compiler    : gcc
#
#     CPU baseline  :
#       Requested   : optimization disabled
#       Enabled     : none
#       Flags       : none
#       Extra checks: none
#       Requested   : optimization disabled
#
#     CPU dispatch  :
#       Enabled     : none
#       Generated   : none
#     CCompilerOpt._cache_write[796] : write cache to path -> /private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-install-fq5ait8j/numpy/build/temp.macosx-10.9-universal2-3.9/ccompiler_opt_cache_ext.py
#
#     ########### CLIB COMPILER OPTIMIZATION ###########
#     Platform      :
#       Architecture: unsupported
#       Compiler    : gcc
#
#     CPU baseline  :
#       Requested   : optimization disabled
#       Enabled     : none
#       Flags       : none
#       Extra checks: none
#       Requested   : optimization disabled
#
#     CPU dispatch  :
#       Enabled     : none
#       Generated   : none
#     CCompilerOpt._cache_write[796] : write cache to path -> /private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-install-fq5ait8j/numpy/build/temp.macosx-10.9-universal2-3.9/ccompiler_opt_cache_clib.py
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#   Failed to build numpy
#   ERROR: Could not build wheels for numpy which use PEP 517 and cannot be installed directly
#   WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
#   You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/50/hrbxd6dd0vx3_pvf2vwfb79h0000gn/T/pip-build-env-8nx0fg15/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.29.21,<3' 'numpy==1.16.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version=='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.5; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version=='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy; python_version>='"'"'3.9'"'"'' Check the logs for full command output.
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
from pandas import Series, DataFrame
import pandas as pandas

fruit = Series([2500, 3800, 1200, 6000], index = ['apple', 'banana', 'peer', 'cherry'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-68ac312b62c9> in <module>
# ----> 1 from pandas import Series, DataFrame
#       2 import pandas as pandas
#       3
#       4 fruit = Series([2500, 3800, 1200, 6000], index = ['apple', 'banana', 'peer', 'cherry'])
#
# ModuleNotFoundError: No module named 'pandas'
